# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from mpl_toolkits.mplot3d import Axes3D  
import IPython.display as IPdisplay
import imageio

# %%
data1 = pd.read_csv("dataset2016-2018.csv")
data1.head(10)
# Out:
#    order_id     bin      payment_type   billing_city  billing_postal_code  \
# 0   9426995  408537              Visa        HAMPTON                 3842
# 1  11614239  412739              Visa           KATY                77494
# 2  11614242  379743  American Express        MADISON                39110
# 3  11614257  400344              Visa       LIVE OAK                32060
# 4  11614281  517760        MasterCard  POMPANO BEACH                33065
# 5  11614283  473703              Visa        NORFOLK                23503
# 6  11614289  437307              Visa    KANSAS CITY                66106
# 7  11614312  416993              Visa        ROYSTON                30662
# 8  11614316  441244              Visa       HEADLAND                36345
# 9  11614349  430326              Visa    WHARNCLIFFE                25651
#
#    retry_indicator                        traffic_provider  M0_Approval%
# 0                0                                     N\A      1.000000
# 1                0  MobileSite-PD-TextLink-SeeExactAddress      1.000000
# 2                0                                      22      1.000000
# 3                0                             PropContact      1.000000
# 4                0                                     N\A      0.000000
# 5                0                     trulia foreclosures      1.000000
# 6                0  MobileSite-PD-TextLink-SeeExactAddress      0.333333
# 7                0                                     N\A      0.000000
# 8                0                          HeaderMenuJoin      1.000000
# 9                0                           Mobile_Banner      0.000000

# %%
# bin_count = data1.groupby('bin')['bin'].nunique()
# bin_count
bin_count = data1['bin'].value_counts()
bin_count = pd.DataFrame({'bin':bin_count.index, 'count':bin_count.values})
bin_count.head(10).style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_ac23b95a_58ee_11ea_8adf_c23225efb41c" ><thead>    <tr>        <th class="col_heading level0 col0" >bin</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_ac23b95a_58ee_11ea_8adf_c23225efb41crow0_col0" class="data row0 col0" >517805</td>
#                         <td id="T_ac23b95a_58ee_11ea_8adf_c23225efb41crow0_col1" class="data row0 col1" >6013</td>
#             </tr>
#             <tr>
#                                 <td id="T_ac23b95a_58ee_11ea_8adf_c23225efb41crow1_col0" class="data row1 col0" >533248</td>
#                         <td id="T_ac23b95a_58ee_11ea_8adf_c23225efb41crow1_col1" class="data row1 col1" >3254</td>
#             </tr>
#             <tr>
#                                 <td id="T_ac23b95a_58ee_11ea_8adf_c23225efb41crow2_col0" class="data row2 col0" >473702</td>
#                         <td id="T_ac23b95a_58ee_11ea_8adf_c23225efb41crow2_col1" class="data row2 col1" >3193</td>
#             </tr>
#             <tr>
#                                 <td id="T_ac23b95a_58ee_11ea_8adf_c23225efb41crow3_col0" class="data row3 col0" >601100</td>
#                         <td id="T_ac23b95a_58ee_11ea_8adf_c23225efb41crow3_col1" class="data row3 col1" >2096</td>
#             </tr>
#             <tr>
#                                 <td id="T_ac23b95a_58ee_11ea_8adf_c23225efb41crow4_col0" class="data row4 col0" >434256</td>
#                         <td id="T_ac23b95a_58ee_11ea_8adf_c23225efb41crow4_col1" class="data row4 col1" >1992</td>
#             </tr>
#             <tr>
#                                 <td id="T_ac23b95a_58ee_11ea_8adf_c23225efb41crow5_col0" class="data row5 col0" >426684</td>
#                         <td id="T_ac23b95a_58ee_11ea_8adf_c23225efb41crow5_col1" class="data row5 col1" >1800</td>
#             </tr>
#             <tr>
#                                 <td id="T_ac23b95a_58ee_11ea_8adf_c23225efb41crow6_col0" class="data row6 col0" >444796</td>
#                         <td id="T_ac23b95a_58ee_11ea_8adf_c23225efb41crow6_col1" class="data row6 col1" >1759</td>
#             </tr>
#             <tr>
#                                 <td id="T_ac23b95a_58ee_11ea_8adf_c23225efb41crow7_col0" class="data row7 col0" >473703</td>
#                         <td id="T_ac23b95a_58ee_11ea_8adf_c23225efb41crow7_col1" class="data row7 col1" >1667</td>
#             </tr>
#             <tr>
#                                 <td id="T_ac23b95a_58ee_11ea_8adf_c23225efb41crow8_col0" class="data row8 col0" >403995</td>
#                         <td id="T_ac23b95a_58ee_11ea_8adf_c23225efb41crow8_col1" class="data row8 col1" >1643</td>
#             </tr>
#             <tr>
#                                 <td id="T_ac23b95a_58ee_11ea_8adf_c23225efb41crow9_col0" class="data row9 col0" >400022</td>
#                         <td id="T_ac23b95a_58ee_11ea_8adf_c23225efb41crow9_col1" class="data row9 col1" >1560</td>
#             </tr>
#     </tbody></table>

# %%
fig = plt.figure(figsize=[20,10])

ax = fig.add_subplot(2,1,1, projection='3d')

yticks = data1['retry_indicator']

surf = ax.plot_trisurf(data1['bin'], data1['retry_indicator'],data1['M0_Approval%'] , 
                       cmap=cm.coolwarm, linewidth=0)
fig.colorbar(surf, shrink=0.5, aspect=5)

labelsize=15
ax.set_xlabel('Bin', fontsize=labelsize)
ax.set_ylabel('Retry', fontsize=labelsize)
ax.set_zlabel('M0_Approval%', fontsize=labelsize)
ax.set_title('The front', fontsize=15, x=0.5, y=1.04)

ax.set_yticks( yticks )
ax.tick_params(axis='both', labelsize=10 )


ax = fig.add_subplot(2,1,2, projection='3d')

yticks = data1['retry_indicator']

surf = ax.plot_trisurf(data1['bin'], data1['retry_indicator'],data1['M0_Approval%'] , 
                       cmap=cm.coolwarm, linewidth=0)
fig.colorbar(surf, shrink=0.5, aspect=5)

labelsize=15
ax.set_xlabel('Bin', fontsize=labelsize)
ax.set_ylabel('Retry', fontsize=labelsize)
ax.set_zlabel('M0_Approval%', fontsize=labelsize)
ax.set_title('The front', fontsize=15, x=0.5, y=1.04)

ax.set_yticks( yticks )
ax.tick_params(axis='both', labelsize=10 )


ax.view_init(30, 80)
plt.show()

# %%
test = data1.groupby(['order_id', 'bin']).size()
[item[1] for item in test.index]

if 517805 in [item[1] for item in test.index]:
    print('True')
# Out:
# True

# %%
bin_count['count'].shape
data1['bin'].shape
# Out:
# (173763,)

# %%
fig = plt.figure(figsize=[20,10])

ax = fig.add_subplot(2,1,1, projection='3d')

yticks = bin_count['count']

surf = ax.plot_trisurf(bin_count['bin'], bin_count['count'],data1['M0_Approval%'] , 
                       cmap=cm.coolwarm, linewidth=0)
fig.colorbar(surf, shrink=0.5, aspect=5)

labelsize=15
ax.set_xlabel('Bin', fontsize=labelsize)
ax.set_ylabel('Number of Occurrence', fontsize=labelsize)
ax.set_zlabel('M0_Approval%', fontsize=labelsize)
ax.set_title('The front of implied volatility surface', fontsize=15, x=0.5, y=1.04)

ax.set_yticks( yticks )
ax.tick_params(axis='both', labelsize=10 )


ax = fig.add_subplot(2,1,2, projection='3d')

yticks = bin_count['count']

surf = ax.plot_trisurf(bin_count['bin'], bin_count['count'],data1['M0_Approval%'] , 
                       cmap=cm.coolwarm, linewidth=0)
fig.colorbar(surf, shrink=0.5, aspect=5)

labelsize=15
ax.set_xlabel('Bin', fontsize=labelsize)
ax.set_ylabel('Number of Occurrence', fontsize=labelsize)
ax.set_zlabel('M0_Approval%', fontsize=labelsize)
ax.set_title('The back of implied volatility surface', fontsize=15, x=0.5, y=1.04)

ax.set_yticks( yticks )
ax.tick_params(axis='both', labelsize=10 )


ax.view_init(30, 80)
plt.show()
