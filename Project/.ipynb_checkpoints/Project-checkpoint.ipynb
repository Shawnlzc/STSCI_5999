# %% [markdown]
# # STSCI_5999
#
# # Feb.27, 2020

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from mpl_toolkits.mplot3d import Axes3D  
import IPython.display as IPdisplay
import imageio

# %%
data1 = pd.read_csv("dataset2016-2018.csv")
data1.head(10)
# Out:
#    order_id     bin      payment_type   billing_city  billing_postal_code  \
# 0   9426995  408537              Visa        HAMPTON                 3842
# 1  11614239  412739              Visa           KATY                77494
# 2  11614242  379743  American Express        MADISON                39110
# 3  11614257  400344              Visa       LIVE OAK                32060
# 4  11614281  517760        MasterCard  POMPANO BEACH                33065
# 5  11614283  473703              Visa        NORFOLK                23503
# 6  11614289  437307              Visa    KANSAS CITY                66106
# 7  11614312  416993              Visa        ROYSTON                30662
# 8  11614316  441244              Visa       HEADLAND                36345
# 9  11614349  430326              Visa    WHARNCLIFFE                25651
#
#    retry_indicator                        traffic_provider  M0_Approval%
# 0                0                                     N\A      1.000000
# 1                0  MobileSite-PD-TextLink-SeeExactAddress      1.000000
# 2                0                                      22      1.000000
# 3                0                             PropContact      1.000000
# 4                0                                     N\A      0.000000
# 5                0                     trulia foreclosures      1.000000
# 6                0  MobileSite-PD-TextLink-SeeExactAddress      0.333333
# 7                0                                     N\A      0.000000
# 8                0                          HeaderMenuJoin      1.000000
# 9                0                           Mobile_Banner      0.000000

# %%
# bin_count = data1.groupby('bin')['bin'].nunique()
# bin_count
bin_count = data1['bin'].value_counts()
bin_count = pd.DataFrame({'bin':bin_count.index, 'count':bin_count.values})
bin_count.head(10).style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_70003712_60fe_11ea_aa57_f43909320f0c" ><thead>    <tr>        <th class="col_heading level0 col0" >bin</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_70003712_60fe_11ea_aa57_f43909320f0crow0_col0" class="data row0 col0" >517805</td>
#                         <td id="T_70003712_60fe_11ea_aa57_f43909320f0crow0_col1" class="data row0 col1" >6013</td>
#             </tr>
#             <tr>
#                                 <td id="T_70003712_60fe_11ea_aa57_f43909320f0crow1_col0" class="data row1 col0" >533248</td>
#                         <td id="T_70003712_60fe_11ea_aa57_f43909320f0crow1_col1" class="data row1 col1" >3254</td>
#             </tr>
#             <tr>
#                                 <td id="T_70003712_60fe_11ea_aa57_f43909320f0crow2_col0" class="data row2 col0" >473702</td>
#                         <td id="T_70003712_60fe_11ea_aa57_f43909320f0crow2_col1" class="data row2 col1" >3193</td>
#             </tr>
#             <tr>
#                                 <td id="T_70003712_60fe_11ea_aa57_f43909320f0crow3_col0" class="data row3 col0" >601100</td>
#                         <td id="T_70003712_60fe_11ea_aa57_f43909320f0crow3_col1" class="data row3 col1" >2096</td>
#             </tr>
#             <tr>
#                                 <td id="T_70003712_60fe_11ea_aa57_f43909320f0crow4_col0" class="data row4 col0" >434256</td>
#                         <td id="T_70003712_60fe_11ea_aa57_f43909320f0crow4_col1" class="data row4 col1" >1992</td>
#             </tr>
#             <tr>
#                                 <td id="T_70003712_60fe_11ea_aa57_f43909320f0crow5_col0" class="data row5 col0" >426684</td>
#                         <td id="T_70003712_60fe_11ea_aa57_f43909320f0crow5_col1" class="data row5 col1" >1800</td>
#             </tr>
#             <tr>
#                                 <td id="T_70003712_60fe_11ea_aa57_f43909320f0crow6_col0" class="data row6 col0" >444796</td>
#                         <td id="T_70003712_60fe_11ea_aa57_f43909320f0crow6_col1" class="data row6 col1" >1759</td>
#             </tr>
#             <tr>
#                                 <td id="T_70003712_60fe_11ea_aa57_f43909320f0crow7_col0" class="data row7 col0" >473703</td>
#                         <td id="T_70003712_60fe_11ea_aa57_f43909320f0crow7_col1" class="data row7 col1" >1667</td>
#             </tr>
#             <tr>
#                                 <td id="T_70003712_60fe_11ea_aa57_f43909320f0crow8_col0" class="data row8 col0" >403995</td>
#                         <td id="T_70003712_60fe_11ea_aa57_f43909320f0crow8_col1" class="data row8 col1" >1643</td>
#             </tr>
#             <tr>
#                                 <td id="T_70003712_60fe_11ea_aa57_f43909320f0crow9_col0" class="data row9 col0" >400022</td>
#                         <td id="T_70003712_60fe_11ea_aa57_f43909320f0crow9_col1" class="data row9 col1" >1560</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Data visualization

# %%
fig = plt.figure(figsize=[20,10])

ax = fig.add_subplot(2,1,1, projection='3d')

yticks = data1['retry_indicator']

surf = ax.plot_trisurf(data1['bin'], data1['retry_indicator'],data1['M0_Approval%'] , 
                       cmap=cm.coolwarm, linewidth=0)
fig.colorbar(surf, shrink=0.5, aspect=5)

labelsize=15
ax.set_xlabel('Bin', fontsize=labelsize)
ax.set_ylabel('Retry', fontsize=labelsize)
ax.set_zlabel('M0_Approval%', fontsize=labelsize)
ax.set_title('Front View', fontsize=15, x=0.5, y=1.04)

ax.set_yticks( yticks )
ax.tick_params(axis='both', labelsize=10 )


ax = fig.add_subplot(2,1,2, projection='3d')

yticks = data1['retry_indicator']

surf = ax.plot_trisurf(data1['bin'], data1['retry_indicator'],data1['M0_Approval%'] , 
                       cmap=cm.coolwarm, linewidth=0)
fig.colorbar(surf, shrink=0.5, aspect=5)

labelsize=15
ax.set_xlabel('Bin', fontsize=labelsize)
ax.set_ylabel('Retry', fontsize=labelsize)
ax.set_zlabel('M0_Approval%', fontsize=labelsize)
ax.set_title('Back View', fontsize=15, x=0.5, y=1.04)

ax.set_yticks( yticks )
ax.tick_params(axis='both', labelsize=10 )


ax.view_init(30, 80)
plt.show()

# %%
fig = plt.figure(figsize=[15,10])

yticks = data1['retry_indicator']

ax =fig.add_subplot(111, projection='3d')

surf = ax.plot_trisurf(data1['bin'], data1['retry_indicator'],data1['M0_Approval%'] , 
                       cmap=cm.coolwarm, linewidth=0)
fig.colorbar(surf, shrink=0.5, aspect=5)

labelsize=15
ax.set_xlabel('Bin', fontsize=labelsize)
ax.set_ylabel('Retry', fontsize=labelsize)
ax.set_zlabel('M0_Approval%', fontsize=labelsize)
ax.set_title('Bin - Retry - Approval', fontsize=15, x=0.5, y=1.04)

ax.set_yticks( yticks )
ax.tick_params(axis='both', labelsize=10 )

gif_filename='Bin_Retry_Approval'

filenames=[]

#Rotating
for n in range(-120, 120, 2):
    ax.view_init(30, n)
    plt.savefig('images/' + gif_filename + '/img' + str(n).zfill(3) + '.png',
                bbox_inches='tight')
    filenames.append('images/' + gif_filename + '/img' + str(n).zfill(3) + '.png')

plt.close()


file_path_name =  gif_filename + '.gif'

#Making .gif
images = []
for filename in filenames:
    images.append(imageio.imread(filename))
imageio.mimsave(file_path_name , images)

#Display .gif
IPdisplay.Image(url=file_path_name)
# Out:
# <img src="Bin_Retry_Approval.gif"/>

# %% [markdown]
# ### Conclusion from the graph:
#
# * Better "bins" are shown in the "red" part.
# * Bins within 350000 to 550000 are more likely to have higher approval rates, this result agree with our plot from R.
# * Bins with high "retry" attempts will more likely to have lower approval rates.
#
# From this plot we know the overall distribution of the data.
# Next, we can try some clustering methods that can hopefully generate a more accurate way to seperate the "red" part.

# %% [markdown]
# ---

# %% [markdown]
# ## Decision tree

# %%
import graphviz
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from graphviz import Source

# %%
# X is the feature variables that contains 'bin' and 'retry_indicator' columns.
# To make classification, change 'M0_Approval%' to 0 or 1 with specific threshold.
feature_cols = ['bin', 'retry_indicator'] 
X = data1[feature_cols].astype(object)

### Threshold can be changed here ###
threshold = 0.5
approval_indicator = np.where(data1['M0_Approval%'] > threshold, 1, 0)
data1['Approval_indicator'] = approval_indicator


Y = data1.Approval_indicator
data1.head(10)
# Out:
#    order_id     bin      payment_type   billing_city  billing_postal_code  \
# 0   9426995  408537              Visa        HAMPTON                 3842
# 1  11614239  412739              Visa           KATY                77494
# 2  11614242  379743  American Express        MADISON                39110
# 3  11614257  400344              Visa       LIVE OAK                32060
# 4  11614281  517760        MasterCard  POMPANO BEACH                33065
# 5  11614283  473703              Visa        NORFOLK                23503
# 6  11614289  437307              Visa    KANSAS CITY                66106
# 7  11614312  416993              Visa        ROYSTON                30662
# 8  11614316  441244              Visa       HEADLAND                36345
# 9  11614349  430326              Visa    WHARNCLIFFE                25651
#
#    retry_indicator                        traffic_provider  M0_Approval%  \
# 0                0                                     N\A      1.000000
# 1                0  MobileSite-PD-TextLink-SeeExactAddress      1.000000
# 2                0                                      22      1.000000
# 3                0                             PropContact      1.000000
# 4                0                                     N\A      0.000000
# 5                0                     trulia foreclosures      1.000000
# 6                0  MobileSite-PD-TextLink-SeeExactAddress      0.333333
# 7                0                                     N\A      0.000000
# 8                0                          HeaderMenuJoin      1.000000
# 9                0                           Mobile_Banner      0.000000
#
#    Approval_indicator
# 0                   1
# 1                   1
# 2                   1
# 3                   1
# 4                   0
# 5                   1
# 6                   0
# 7                   0
# 8                   1
# 9                   0

# %%
Approval_count = data1['Approval_indicator'].value_counts()
Approval_count = pd.DataFrame({'Indicator':Approval_count.index, 'count':Approval_count.values})
display(Approval_count.head(10).style.hide_index())
# plt.bar(Approval_count['Indicator'], Approval_count['count'])
# plt.show()
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x = ['1', '0']
ax.bar(x,Approval_count['count'])
plt.show()
# Out:
# <style  type="text/css" >
# </style><table id="T_74c5c76e_60fe_11ea_947e_f43909320f0c" ><thead>    <tr>        <th class="col_heading level0 col0" >Indicator</th>        <th class="col_heading level0 col1" >count</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_74c5c76e_60fe_11ea_947e_f43909320f0crow0_col0" class="data row0 col0" >1</td>
#                         <td id="T_74c5c76e_60fe_11ea_947e_f43909320f0crow0_col1" class="data row0 col1" >128581</td>
#             </tr>
#             <tr>
#                                 <td id="T_74c5c76e_60fe_11ea_947e_f43909320f0crow1_col0" class="data row1 col0" >0</td>
#                         <td id="T_74c5c76e_60fe_11ea_947e_f43909320f0crow1_col1" class="data row1 col1" >45182</td>
#             </tr>
#     </tbody></table>

# %%
# Split dataset into 50% training and 50% test
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.5, random_state = None) 
X_train.head(10)
# Out:
#            bin retry_indicator
# 152978  559332               0
# 32925   402944               0
# 169995  420767               0
# 79538   465642               0
# 137037  533248               0
# 31814   423817               0
# 155383  531259               0
# 34253   510805               2
# 142032  468271               0
# 52197   511028               0

# %% [markdown]
# The following cell displays a decision tree after pruning.
#
# *Note: The full decision tree is too large to be performed by my PC. Therefore, I used Google Colab to generate the full tree, as shown in the file "Full_tree.png".*

# %%
# Decision tree with pruning.

clf = tree.DecisionTreeClassifier(max_depth = 5)
clf.fit(X_train, Y_train)

graph = Source(tree.export_graphviz(clf, out_file=None, feature_names=X.columns, class_names=['0', '1'], filled=True))
graph.format = 'png'
graph.render('Pruned',view = True)

# Display the tree
IPdisplay.Image('Pruned.png')

# %%
# Predict the response for test dataset
Y_pred = clf.predict(X_test)
print("Accuracy:",round(metrics.accuracy_score(Y_test, Y_pred) * 100, 2), "%")
# Out:
# Accuracy: 80.89 %

# %% [markdown]
# ### Conclusion: A simply decision tree with 5 layers can achieve about 81% accuracy.
# Next, lets try to find a better model without overfitting.

# %%
optimal_depth = []
tree_accuracy = []
for depth in range(1, 100):
    optimal_depth.append(depth)
    clf = tree.DecisionTreeClassifier(max_depth = depth)
    clf.fit(X_train, Y_train)
    Y_pred = clf.predict(X_test)
    tree_accuracy.append(metrics.accuracy_score(Y_test, Y_pred))


print("Optimal depth:", optimal_depth[tree_accuracy.index(max(tree_accuracy))])
print("Accuracy:", round(max(tree_accuracy)*100, 2), "%")
plt.plot(optimal_depth, tree_accuracy)
plt.show()
# Out:
# Optimal depth: 14
# Accuracy: 83.61 %

# %% [markdown]
# ### Conclusion: depth = 16 decision tree gives us a more accurate prediction, with 83.98% accuracy.
# Note: Other optionals like criterion="entropy" etc. may improve the accuracy as well.
#
# For example, change the line to:
#
# > clf = tree.DecisionTreeClassifier(**criterion="entropy"**, max_depth = depth)
#
# Since the idea is similar, we won't repeat in here.

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier 
clf_RF = RandomForestClassifier(n_estimators=1000)
clf_RF.fit(X_train,Y_train)
Y_pred=clf_RF.predict(X_test)
print(metrics.accuracy_score(Y_test, Y_pred))
# print("Accuracy:",round(metrics.accuracy_score(Y_test, Y_pred) * 100, 2), "%")

# %%
# optimal_depth = []
# tree_accuracy = []
# for depth in range(1, 1000):
#     optimal_depth.append(depth)
#     clf_RF = RandomForestClassifier(n_estimators=depth)
#     clf.fit(X_train, Y_train)
#     Y_pred = clf.predict(X_test)
#     tree_accuracy.append(metrics.accuracy_score(Y_test, Y_pred))


# print("Optimal depth:", optimal_depth[tree_accuracy.index(max(tree_accuracy))])
# print("Accuracy:", round(max(tree_accuracy)*100, 2), "%")
# plt.plot(optimal_depth, tree_accuracy)
# plt.show()

# %%
0.8361685964871896

# %%
# test = data1.groupby(['order_id', 'bin']).size()
# [item[1] for item in test.index]

# if 517805 in [item[1] for item in test.index]:
#     print('True')

# %%
# bin_count['count'].shape
# data1['bin'].shape

# %%
##### Export to html #####
# import os

# os.system('jupyter nbconvert --to html Project.ipynb')
# Out:
# 0
